# %% [markdown]
# # Análise Exploratória - DATATHON FIAP 2026
#
# Este notebook carrega e analiza os dados do programa PEDE (Programa de Desenvolvimento Educacional) dos anos 2022, 2023 e 2024.

# %%
# Importar bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys, os

sys.path.append(os.path.abspath('..'))

# importar funções úteis do módulo de preprocessing
from src.preprocessing import *

# Configurar visualização
# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12

# %%
# Carregar o arquivo Excel
file_path = r'C:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\Base_pede.xlsx'

# Carregar os dados de cada ano
df_2022 = pd.read_excel(file_path, sheet_name='PEDE2022')
df_2023 = pd.read_excel(file_path, sheet_name='PEDE2023')
df_2024 = pd.read_excel(file_path, sheet_name='PEDE2024')

print("=" * 60)
print("INFORMAÇÕES DO DATASET")
print("=" * 60)
print(f"\nPEDE2022: {df_2022.shape[0]} linhas, {df_2022.shape[1]} colunas")
print(f"PEDE2023: {df_2023.shape[0]} linhas, {df_2023.shape[1]} colunas")
print(f"PEDE2024: {df_2024.shape[0]} linhas, {df_2024.shape[1]} colunas")
# Out:
# ============================================================
# INFORMAÇÕES DO DATASET
# ============================================================
#
# PEDE2022: 860 linhas, 42 colunas
# PEDE2023: 1014 linhas, 48 colunas
# PEDE2024: 1156 linhas, 50 colunas

# %%
# padroniza para 2022
df22, resumo_22 = padronizar_colunas(df_2022, column_mapping, year=2022)

print(resumo_22['renomeadas'])
print(resumo_22['excluidas'])
# Out:
# {'Nome': 'NOME', 'Instituição de ensino': 'INSTITUICAO_ENSINO_ALUNO', 'Idade 22': 'IDADE_ALUNO', 'Fase': 'FASE', 'INDE 22': 'INDE', 'Pedra 22': 'PEDRA', 'Destaque IEG': 'DESTAQUE_IEG', 'Destaque IDA': 'DESTAQUE_IDA', 'Destaque IPV': 'DESTAQUE_IPV', 'Turma': 'TURMA', 'Rec Psicologia': 'REC_PSICO', 'Rec Av1': 'REC_AVAL_1', 'Rec Av2': 'REC_AVAL_2', 'Rec Av3': 'REC_AVAL_3', 'Rec Av4': 'REC_AVAL_4', 'Fase ideal': 'NIVEL_IDEAL', 'Defas': 'DEFASAGEM', 'Ano ingresso': 'ANO_INGRESSO', 'Cg': 'CG', 'Cf': 'CF', 'Ct': 'CT', 'Portug': 'NOTA_PORT', 'Matem': 'NOTA_MAT', 'Inglês': 'NOTA_ING', 'Nº Av': 'QTDE_AVAL'}
# ['Ano nasc', 'Gênero', 'Pedra 20', 'Pedra 21', 'Avaliador1', 'Avaliador2', 'Avaliador3', 'Avaliador4', 'Indicado', 'Atingiu PV']

# %%
# padroniza para 2023
df23, resumo_23 = padronizar_colunas(df_2023, column_mapping, year=2023)

print(resumo_23['renomeadas'])
print(resumo_23['excluidas'])
# Out:
# {'Nome Anonimizado': 'NOME', 'Instituição de ensino': 'INSTITUICAO_ENSINO_ALUNO', 'Idade': 'IDADE_ALUNO', 'Fase': 'FASE', 'INDE 2023': 'INDE', 'Pedra 2023': 'PEDRA', 'Destaque IEG': 'DESTAQUE_IEG', 'Destaque IDA': 'DESTAQUE_IDA', 'Destaque IPV': 'DESTAQUE_IPV', 'Turma': 'TURMA', 'Rec Psicologia': 'REC_PSICO', 'Rec Av1': 'REC_AVAL_1', 'Rec Av2': 'REC_AVAL_2', 'Rec Av3': 'REC_AVAL_3', 'Rec Av4': 'REC_AVAL_4', 'Fase Ideal': 'NIVEL_IDEAL', 'Defasagem': 'DEFASAGEM', 'Ano ingresso': 'ANO_INGRESSO', 'Cg': 'CG', 'Cf': 'CF', 'Ct': 'CT', 'Por': 'NOTA_PORT', 'Mat': 'NOTA_MAT', 'Ing': 'NOTA_ING', 'Nº Av': 'QTDE_AVAL'}
# ['Data de Nasc', 'Gênero', 'Pedra 20', 'Pedra 21', 'Pedra 22', 'Pedra 23', 'INDE 22', 'INDE 23', 'Avaliador1', 'Avaliador2', 'Avaliador3', 'Avaliador4', 'Indicado', 'Atingiu PV', 'Destaque IPV.1']

# %%
# padroniza para 2024
df24, resumo_24 = padronizar_colunas(df_2024, column_mapping, year=2024)

print(resumo_24['renomeadas'])
print(resumo_24['excluidas'])
# Out:
# {'Nome Anonimizado': 'NOME', 'Instituição de ensino': 'INSTITUICAO_ENSINO_ALUNO', 'Idade': 'IDADE_ALUNO', 'Fase': 'FASE', 'INDE 2024': 'INDE', 'Pedra 2024': 'PEDRA', 'Destaque IEG': 'DESTAQUE_IEG', 'Destaque IDA': 'DESTAQUE_IDA', 'Destaque IPV': 'DESTAQUE_IPV', 'Turma': 'TURMA', 'Rec Psicologia': 'REC_PSICO', 'Rec Av1': 'REC_AVAL_1', 'Rec Av2': 'REC_AVAL_2', 'Fase Ideal': 'NIVEL_IDEAL', 'Defasagem': 'DEFASAGEM', 'Ano ingresso': 'ANO_INGRESSO', 'Cg': 'CG', 'Cf': 'CF', 'Ct': 'CT', 'Por': 'NOTA_PORT', 'Mat': 'NOTA_MAT', 'Ing': 'NOTA_ING', 'Nº Av': 'QTDE_AVAL'}
# ['Data de Nasc', 'Gênero', 'Pedra 20', 'Pedra 21', 'Pedra 22', 'Pedra 23', 'INDE 22', 'INDE 23', 'Avaliador1', 'Avaliador2', 'Avaliador3', 'Avaliador4', 'Avaliador5', 'Avaliador6', 'Indicado', 'Atingiu PV', 'Escola', 'Ativo/ Inativo', 'Ativo/ Inativo.1']

# %%
#Unificar os datasets padronizados
df_pede = pd.concat([df22, df23, df24], ignore_index=True)
df_pede[df_pede["ANO_BASE"] == '2024'].head()
# Out:
#            RA  FASE           TURMA        NOME IDADE_ALUNO  ANO_INGRESSO  \
# 1874  RA-1275  ALFA  ALFA A - G0/G1  Aluno-1275           8          2024
# 1875  RA-1276  ALFA  ALFA A - G0/G1  Aluno-1276           8          2024
# 1876  RA-1277  ALFA  ALFA A - G0/G1  Aluno-1277           8          2024
# 1877   RA-868  ALFA  ALFA A - G0/G1   Aluno-868           8          2023
# 1878  RA-1278  ALFA  ALFA A - G0/G1  Aluno-1278           9          2024
#
#      INSTITUICAO_ENSINO_ALUNO     PEDRA      INDE  CG  ...  NOTA_ING  \
# 1874                  Pública  Ametista  7.611367 NaN  ...       NaN
# 1875                  Pública   Topázio  8.002867 NaN  ...       NaN
# 1876                  Pública  Ametista    7.9522 NaN  ...       NaN
# 1877                  Pública  Ametista  7.156367 NaN  ...       NaN
# 1878                  Pública   Quartzo    5.4442 NaN  ...       NaN
#
#            IPV   IAN           NIVEL_IDEAL DEFASAGEM DESTAQUE_IEG  \
# 1874  5.446667  10.0    ALFA (1° e 2° ano)         0          NaN
# 1875  7.050000  10.0    ALFA (1° e 2° ano)         0          NaN
# 1876  7.046667  10.0    ALFA (1° e 2° ano)         0          NaN
# 1877  7.213333   5.0  Fase 1 (3° e 4° ano)        -1          NaN
# 1878  4.173333   5.0  Fase 1 (3° e 4° ano)        -1          NaN
#
#      DESTAQUE_IDA  DESTAQUE_IPV  ANO_BASE    IPP
# 1874          NaN           NaN      2024  5.625
# 1875          NaN           NaN      2024  7.500
# 1876          NaN           NaN      2024  7.500
# 1877          NaN           NaN      2024  6.875
# 1878          NaN           NaN      2024  5.000
#
# [5 rows x 34 columns]

# %%
# Tipos de dados - PEDE2024
print("\nTipos de dados - PEDE:")
print(df_pede.info())
# Out:
# Tipos de dados - PEDE:
# <class 'pandas.DataFrame'>
# RangeIndex: 3030 entries, 0 to 3029
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   RA                        3030 non-null   str
#  1   FASE                      3030 non-null   object
#  2   TURMA                     3030 non-null   object
#  3   NOME                      3030 non-null   str
#  4   IDADE_ALUNO               3030 non-null   object
#  5   ANO_INGRESSO              3030 non-null   int64
#  6   INSTITUICAO_ENSINO_ALUNO  3029 non-null   str
#  7   PEDRA                     2883 non-null   str
#  8   INDE                      2883 non-null   object
#  9   CG                        860 non-null    float64
#  10  CF                        860 non-null    float64
#  11  CT                        860 non-null    float64
#  12  QTDE_AVAL                 2954 non-null   float64
#  13  REC_AVAL_1                860 non-null    object
#  14  REC_AVAL_2                860 non-null    object
#  15  REC_AVAL_3                860 non-null    object
#  16  REC_AVAL_4                296 non-null    object
#  17  IAA                       2865 non-null   float64
#  18  IEG                       2954 non-null   float64
#  19  IPS                       2859 non-null   float64
#  20  REC_PSICO                 860 non-null    object
#  21  IDA                       2852 non-null   float64
#  22  NOTA_MAT                  2846 non-null   float64
#  23  NOTA_PORT                 2845 non-null   float64
#  24  NOTA_ING                  1091 non-null   float64
#  25  IPV                       2852 non-null   float64
#  26  IAN                       3030 non-null   float64
#  27  NIVEL_IDEAL               3030 non-null   str
#  28  DEFASAGEM                 3030 non-null   int64
#  29  DESTAQUE_IEG              860 non-null    object
#  30  DESTAQUE_IDA              860 non-null    object
#  31  DESTAQUE_IPV              860 non-null    object
#  32  ANO_BASE                  3030 non-null   str
#  33  IPP                       1992 non-null   float64
# dtypes: float64(14), int64(2), object(12), str(6)
# memory usage: 805.0+ KB
# None

# %%
# Estatísticas descritivas - PEDE2024
print("\nEstatísticas descritivas - PEDE:")
df_pede.describe()
# Out:
# Estatísticas descritivas - PEDE:
#        ANO_INGRESSO          CG          CF          CT    QTDE_AVAL  \
# count   3030.000000  860.000000  860.000000  860.000000  2954.000000
# mean    2021.563696  430.516279   75.519767    6.598837     3.031821
# std        1.822171  248.432761   52.312670    3.975858     1.063670
# min     2016.000000    1.000000    1.000000    1.000000     0.000000
# 25%     2021.000000  215.750000   30.000000    3.000000     2.000000
# 50%     2022.000000  430.500000   67.000000    6.000000     3.000000
# 75%     2023.000000  645.250000  118.000000    9.000000     4.000000
# max     2024.000000  862.000000  192.000000   18.000000     6.000000
#
#                IAA          IEG          IPS          IDA     NOTA_MAT  \
# count  2865.000000  2954.000000  2859.000000  2852.000000  2846.000000
# mean      7.918225     7.945696     6.287129     6.375964     6.161595
# std       2.626209     2.152281     1.792491     1.956637     2.398341
# min       0.000000     0.000000     2.500000     0.000000     0.000000
# 25%       7.900000     7.300000     5.020000     5.100000     4.800000
# 50%       8.751000     8.600000     7.500000     6.666667     6.300000
# 75%       9.500000     9.400000     7.510000     7.833333     8.000000
# max      10.002000    10.000000    10.000000    10.000000    10.000000
#
#          NOTA_PORT     NOTA_ING          IPV          IAN    DEFASAGEM  \
# count  2845.000000  1091.000000  2852.000000  3030.000000  3030.000000
# mean      6.430668     6.289413     7.545476     7.179043    -0.642904
# std       2.138916     2.732636     1.084347     2.535266     0.866382
# min       0.000000     0.000000     2.500000     2.500000    -5.000000
# 25%       5.200000     4.500000     6.984000     5.000000    -1.000000
# 50%       6.700000     6.700000     7.583000     5.000000    -1.000000
# 75%       8.000000     8.500000     8.255000    10.000000     0.000000
# max      10.000000    10.000000    10.010000    10.000000     3.000000
#
#                IPP
# count  1992.000000
# mean      7.555203
# std       0.938990
# min       2.500000
# 25%       7.083333
# 50%       7.500000
# 75%       8.125000
# max      10.000000

# %%
# Verificar valores nulos - PEDE
print("\nValores nulos por coluna - PEDE:")
null_counts = df_pede.isnull().sum()
null_pct = (null_counts / len(df_pede)) * 100
null_df = pd.DataFrame({'Quantidade': null_counts, 'Porcentagem': null_pct})
print(null_df[null_df['Quantidade'] > 0].sort_values('Quantidade', ascending=False))
# Out:
# Valores nulos por coluna - PEDE:
#                           Quantidade  Porcentagem
# REC_AVAL_4                      2734    90.231023
# CG                              2170    71.617162
# CT                              2170    71.617162
# REC_AVAL_1                      2170    71.617162
# REC_PSICO                       2170    71.617162
# REC_AVAL_3                      2170    71.617162
# REC_AVAL_2                      2170    71.617162
# CF                              2170    71.617162
# DESTAQUE_IPV                    2170    71.617162
# DESTAQUE_IEG                    2170    71.617162
# DESTAQUE_IDA                    2170    71.617162
# NOTA_ING                        1939    63.993399
# IPP                             1038    34.257426
# NOTA_PORT                        185     6.105611
# NOTA_MAT                         184     6.072607
# IDA                              178     5.874587
# IPV                              178     5.874587
# IPS                              171     5.643564
# IAA                              165     5.445545
# PEDRA                            147     4.851485
# INDE                             147     4.851485
# QTDE_AVAL                         76     2.508251
# IEG                               76     2.508251
# INSTITUICAO_ENSINO_ALUNO           1     0.033003

# %%
# Análise da variável INDE (Índice de Desenvolvimento Educacional)
import traceback
try:
    inde_col = 'INDE'

    # converter para numérico, coercing errors para NaN
    inde_series = pd.to_numeric(df_pede.get(inde_col, pd.Series(dtype='float')), errors='coerce')
    inde_series = inde_series.dropna()

    if inde_series.empty:
        print('Não há valores numéricos válidos na coluna INDE para plotar.')
    else:
        fig, axes = plt.subplots(1, 2, figsize=(14, 5))

        # Histograma
        axes[0].hist(inde_series, bins=30, edgecolor='black', alpha=0.7)
        axes[0].set_xlabel('INDE')
        axes[0].set_ylabel('Frequência')
        axes[0].set_title('Distribuição do INDE')

        # Boxplot
        axes[1].boxplot(inde_series)
        axes[1].set_ylabel('INDE')
        axes[1].set_title('Boxplot do INDE')

        plt.tight_layout()
        plt.show()

        print(f"\nEstatísticas do INDE:")
        print(inde_series.describe())

except Exception:
    print('Erro ao analisar INDE:')
    traceback.print_exc()
# Out:
# Estatísticas do INDE:
# count    2845.000000
# mean        7.269915
# std         0.991767
# min         3.032000
# 25%         6.675200
# 50%         7.388267
# 75%         7.986867
# max         9.531325
# Name: INDE, dtype: float64

# %%
# Análise da variável Pedra
pedra_col = 'PEDRA'

# Contagem de cada categoria
pedra_counts = df_pede[pedra_col].value_counts()

plt.figure(figsize=(10, 6))
pedra_counts.plot(kind='bar', color='steelblue', edgecolor='black')
plt.xlabel('Pedra')
plt.ylabel('Quantidade')
plt.title('Distribuição da Pedra')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print("\nContagem por Pedra:")
print(pedra_counts)
# Out:
# Contagem por Pedra:
# PEDRA
# Ametista    1120
# Topázio      688
# Agata        471
# Quartzo      316
# Ágata        250
# INCLUIR       38
# Name: count, dtype: int64

# %%
# Análise de Idade (robusto)
import traceback
try:
    idade_col = 'IDADE_ALUNO'

    if idade_col not in df_pede.columns:
        print(f"Coluna {idade_col} não encontrada em df_pede.")
    else:
        s = df_pede[idade_col]

        # tratar datetime -> converter para anos (idade aproximada)
        if pd.api.types.is_datetime64_any_dtype(s) or pd.api.types.is_datetime64_dtype(s):
            ref = pd.Timestamp.today()
            idade_series = (ref - s).dt.days / 365.25
        else:
            # primeiro tentar extrair ano se houver datas como strings reconhecíveis
            try:
                s_dt = pd.to_datetime(s, errors='coerce')
            except Exception:
                s_dt = pd.Series([pd.NaT] * len(s))

            if s_dt.notna().any():
                ref = pd.Timestamp.today()
                idade_series = (ref - s_dt).dt.days / 365.25
            else:
                # converter diretamente para numérico (int/float strings)
                idade_series = pd.to_numeric(s, errors='coerce')

        idade_series = idade_series.dropna()

        if idade_series.empty:
            print('Não há valores de idade válidos para plotar.')
        else:
            plt.figure(figsize=(10, 6))
            plt.hist(idade_series, bins=20, edgecolor='black', alpha=0.7)
            plt.xlabel('Idade (anos)')
            plt.ylabel('Frequência')
            plt.title('Distribuição de Idade')
            plt.tight_layout()
            plt.show()

            print("\nEstatísticas de Idade:")
            print(idade_series.describe())

except Exception:
    print('Erro na análise de Idade:')
    traceback.print_exc()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       3 idade_trat = pd.to_numeric(df_pede.get(inde_col, pd.Series(dtype='float')), errors='coerce')
#       5 plt.figure(figsize=(10, 6))
# ----> 6 df_pede[idade_col].hist(bins=20, edgecolor='black', alpha=0.7)
#       7 plt.xlabel('Idade')
#       8 plt.ylabel('Frequência')
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\pandas\plotting\_core.py:132, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      65 """
#      66 Draw histogram of the input series using matplotlib.
#      67
#    (...)    129     >>> hist = ser.groupby(level=0).hist()
#     130 """
#     131 plot_backend = _get_plot_backend(backend)
# --> 132 return plot_backend.hist_series(
#     133     self,
#     134     by=by,
#     135     ax=ax,
#     136     grid=grid,
#     137     xlabelsize=xlabelsize,
#     138     xrot=xrot,
#     139     ylabelsize=ylabelsize,
#     140     yrot=yrot,
#     141     figsize=figsize,
#     142     bins=bins,
#     143     legend=legend,
#     144     **kwargs,
#     145 )
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\pandas\plotting\_matplotlib\hist.py:452, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, legend, **kwds)
#     450 if legend:
#     451     kwds["label"] = self.name
# --> 452 ax.hist(values, bins=bins, **kwds)
#     453 if legend:
#     454     ax.legend()
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\matplotlib\axes\_axes.py:7104, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7100 for xi in x:
#    7101     if len(xi):
#    7102         # python's min/max ignore nan,
#    7103         # np.minnan returns nan for all nan input
# -> 7104         xmin = min(xmin, np.nanmin(xi))
#    7105         xmax = max(xmax, np.nanmax(xi))
#    7106 if xmin <= xmax:  # Only happens if we have seen a finite value.
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:363, in nanmin(a, axis, out, keepdims, initial, where)
#     360 else:
#     361     # Slow, but safe for subclasses of ndarray
#     362     a, mask = _replace_nan(a, +np.inf)
# --> 363     res = np.amin(a, axis=axis, out=out, **kwargs)
#     364     if mask is None:
#     365         return res
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\numpy\_core\fromnumeric.py:3278, in amin(a, axis, out, keepdims, initial, where)
#    3265 @array_function_dispatch(_min_dispatcher)
#    3266 def amin(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    3267          where=np._NoValue):
#    3268     """
#    3269     Return the minimum of an array or minimum along an axis.
#    3270
#    (...)   3276     ndarray.min : equivalent method
#    3277     """
# -> 3278     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    3279                           keepdims=keepdims, initial=initial, where=where)
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\numpy\_core\fromnumeric.py:83, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      80         else:
#      81             return reduction(axis=axis, out=out, **passkwargs)
# ---> 83 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# TypeError: '<=' not supported between instances of 'int' and 'datetime.datetime'

# %%
# Comparação entre anos - Quantidade de registros
years = ['2022', '2023', '2024']
counts = [len(df_pede[df_pede["ANO_BASE"] == '2022']), len(df_pede[df_pede["ANO_BASE"] == '2023']), len(df_pede[df_pede["ANO_BASE"] == '2024'])]

plt.figure(figsize=(10, 6))
plt.bar(years, counts, color=['#2ecc71', '#3498db', '#9b59b6'], edgecolor='black')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Registros')
plt.title('Quantidade de Registros por Ano')
for i, v in enumerate(counts):
    plt.text(i, v + 50, str(v), ha='center', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Correlação entre variáveis numéricas - 2024
numeric_cols = df_pede.select_dtypes(include=[np.number]).columns
print(f"Colunas numéricas: {list(numeric_cols)}")

if len(numeric_cols) > 1:
    plt.figure(figsize=(14, 10))
    sns.heatmap(df_pede[numeric_cols].corr(), annot=True, cmap='coolwarm', center=0, fmt='.2f')
    plt.title('Mapa de Correlação - Variáveis Numéricas 2024')
    plt.tight_layout()
    plt.show()
# Out:
# Colunas numéricas: ['ANO_INGRESSO', 'CG', 'CF', 'CT', 'QTDE_AVAL', 'IAA', 'IEG', 'IPS', 'IDA', 'NOTA_MAT', 'NOTA_PORT', 'NOTA_ING', 'IPV', 'IAN', 'DEFASAGEM', 'IPP']
# Colunas numéricas: ['ANO_INGRESSO', 'CG', 'CF', 'CT', 'QTDE_AVAL', 'IAA', 'IEG', 'IPS', 'IDA', 'NOTA_MAT', 'NOTA_PORT', 'NOTA_ING', 'IPV', 'IAN', 'DEFASAGEM', 'IPP']

# %%
# Análise por Fase/Turma
fase_counts = df_pede['NIVEL_IDEAL'].value_counts()

plt.figure(figsize=(10, 6))
fase_counts.plot(kind='bar', color='coral', edgecolor='black')
plt.xlabel('Fase')
plt.ylabel('Quantidade')
plt.title('Distribuição por Fase')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Resumo final
print("=" * 60)
print("RESUMO DA ANÁLISE EXPLORATÓRIA")
print("=" * 60)
print(f"\nDataset PEDE:")
print(f"  - Total de registros: {len(df_pede)}")
print(f"  - Total de colunas: {len(df_pede.columns)}")
print(f"  - Valores nulos: {df_pede.isnull().sum().sum()}")
print(f"  - INDE médio: {df_pede['INDE'].mean():.2f}")
print(f"  - Idade média: {df_pede['IDADE_ALUNO'].mean():.1f} anos")
# Out:
# ============================================================
# RESUMO DA ANÁLISE EXPLORATÓRIA
# ============================================================
#
# Dataset PEDE:
#   - Total de registros: 3030
#   - Total de colunas: 34
#   - Valores nulos: 28919
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 9
#       7 print(f"  - Total de colunas: {len(df_pede.columns)}")
#       8 print(f"  - Valores nulos: {df_pede.isnull().sum().sum()}")
# ----> 9 print(f"  - INDE médio: {df_pede['INDE'].mean():.2f}")
#      10 print(f"  - Idade média: {df_pede['IDADE_ALUNO'].mean():.1f} anos")
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\pandas\core\series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    8063 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#    8064 def mean(
#    8065     self,
#    (...)   8069     **kwargs,
#    8070 ) -> Any:
#    8071     """
#    8072     Return the mean of the values over the requested axis.
#    8073
#    (...)   8111     2.0
#    8112     """
# -> 8113     return NDFrame.mean(
#    8114         self, axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#    8115     )
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\pandas\core\generic.py:11831, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11823 def mean(
#   11824     self,
#   11825     *,
#    (...)  11829     **kwargs,
#   11830 ) -> Series | float:
# > 11831     return self._stat_function(
#   11832         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11833     )
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\pandas\core\generic.py:11785, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11781 nv.validate_func(name, (), kwargs)
#   11783 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11785 return self._reduce(
#   11786     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11787 )
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\pandas\core\series.py:7494, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7489         # GH#47500 - change to TypeError to match other methods
#    7490         raise TypeError(
#    7491             f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    7492             "with non-numeric dtypes."
#    7493         )
# -> 7494     result = op(delegate, skipna=skipna, **kwds)
#    7496 result = maybe_unbox_numpy_scalar(result)
#    7497 return result
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\pandas\core\nanops.py:149, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     147         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148 else:
# --> 149     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     151 return result
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\pandas\core\nanops.py:709, in nanmean(values, axis, skipna, mask)
#     706     dtype_count = dtype
#     708 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 709 the_sum = values.sum(axis, dtype=dtype_sum)
#     710 the_sum = _ensure_numeric(the_sum)
#     712 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\erick\Documents\FIAP\TC\FASE5_DATATHON\venv\Lib\site-packages\numpy\_core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
